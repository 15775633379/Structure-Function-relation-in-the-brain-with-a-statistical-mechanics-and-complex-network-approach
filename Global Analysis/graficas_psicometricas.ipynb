# %%
# !pip install plotly>=4.7.1
# !wget https://github.com/plotly/orca/releases/download/v1.2.1/orca-1.2.1-x86_64.AppImage -O /usr/local/bin/orca
# !chmod +x /usr/local/bin/orca
# !apt-get install xvfb libgtk2.0-0 libgconf-2-4

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os.path import expanduser, join


import itertools
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go

# %%
# Ruta para guardar los datos con las listas de sujetos que se quieren descargar
fdatapoblaciones = '/gdrive/Shareddrives/GENSyR /CNF (Complejidad y NeuroFísica)/Carpeta de trabajo/Tesis Juan y Diego /Datos Poblaciones'

# %%
sexos = ['F', 'M']
puntuaciones = ['+', '-']

tarea = 'Social_Task'
sexo = 'M'
puntuacion = '+'

# %%
psicometricas = ['Endurance_AgeAdj',	'CogFluidComp_AgeAdj',	'ProcSpeed_AgeAdj',	'WM_Task',	'Language_Task',	'Emotion_Task_Face_Media']
personalidades = ['NEOFAC_A',	'NEOFAC_O',	'NEOFAC_C',	'NEOFAC_N',	'NEOFAC_E']

# %%
name = tarea + '_psicometricos.xlsx'
fname = join(fdatapoblaciones, tarea, name)
data = pd.read_excel(fname)

data

data["Subject"] = data["Subject"].astype(str)
data = data.set_axis(list(data['Subject']), axis = 'index')
data = data.drop(columns=['Subject'])
data = data.transpose()

# %%
data
# Out:
#                                   M100-     M100+      M40-      M40+  \
# NEOFAC_A                       0.666667  0.750000  0.687500  0.645833
# NEOFAC_O                       0.893617  0.510638  0.361702  0.574468
# NEOFAC_C                       0.687500  0.812500  0.791667  0.895833
# NEOFAC_N                       0.372093  0.372093  0.534884  0.348837
# NEOFAC_E                       0.574468  0.680851  0.531915  0.617021
# Endurance_AgeAdj               0.863699  0.697170  0.692429  0.787579
# CogFluidComp_AgeAdj            0.906189  0.702501  0.838202  0.747916
# ProcSpeed_AgeAdj               0.813798  0.720094  0.702545  0.746685
# Social_Task_TOM_Perc_TOM       1.000000  1.000000  0.400000  0.400000
# Social_Task_TOM_Median_RT_TOM  0.962869  0.218994  0.739274  0.377622
# WM_Task                        0.656641  0.747181  0.447161  0.556030
# Language_Task                  0.633075  0.654094  0.609264  0.584228
# ...

# %%
data_personalidad = data.loc[personalidades]
data_personalidad = data_personalidad.append(data_personalidad.iloc[[0]])
data_psicometria = data.loc[psicometricas]
data_psicometria = data_psicometria.append(data_psicometria.iloc[[0]])

# %%
data_personalidad
# Out:
#              M100-     M100+      M40-      M40+     F100-     F100+  \
# NEOFAC_A  0.666667  0.750000  0.687500  0.645833  0.833333  0.687500
# NEOFAC_O  0.893617  0.510638  0.361702  0.574468  0.510638  0.574468
# NEOFAC_C  0.687500  0.812500  0.791667  0.895833  0.625000  0.750000
# NEOFAC_N  0.372093  0.372093  0.534884  0.348837  0.372093  0.558140
# NEOFAC_E  0.574468  0.680851  0.531915  0.617021  0.787234  0.723404
# NEOFAC_A  0.666667  0.750000  0.687500  0.645833  0.833333  0.687500
#
#               F20-      F20+
# NEOFAC_A  0.791667  0.812500
# NEOFAC_O  0.468085  0.914894
# NEOFAC_C  0.916667  0.645833
# NEOFAC_N  0.465116  0.325581
# NEOFAC_E  0.510638  0.787234
# NEOFAC_A  0.791667  0.812500

# %%
data_psicometria.keys()[0]
# Out:
# '894067'

# %%
fig = go.Figure()

for sujeto in data.keys():

  fig.add_trace(go.Scatterpolar(r = data_psicometria[sujeto], theta = data_psicometria.index, name = sujeto))#, fill='toself'))


fig.update_layout(title = 'holi', showlegend=True, polar = dict(radialaxis = dict(showticklabels=True, tickangle = 90, angle = 25), angularaxis = dict(showticklabels=True)))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

for sujeto in data.keys():

  fig.add_trace(go.Scatterpolar(r = data_personalidad[sujeto], theta = data_personalidad.index, name = sujeto))#, fill='toself'))


fig.update_layout(title = 'holi', showlegend=True, polar = dict(radialaxis = dict(showticklabels=True, tickangle = 90, angle = 25), angularaxis = dict(showticklabels=True)))


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Graficas entre tareas para las poblaciones
for tarea in tareas:
  if tarea == 'WM_Task_Acc':
    label = 'Memoria Operativa'
  else:
    label = 'Motora'

  fig = go.Figure()

  for sexo in sexos:
    for puntuacion in puntuaciones:

      grupo = sexo + puntuacion
      labels = tarea + label + grupo

      fig.add_trace(go.Scatterpolar(r = dfgrupos['996782'], theta = dfgrupos.index, name = 'sapo'))#, fill='toself'))


  fig.update_layout(title = "Medidas Globales de " + label + ' con Poblaciones de ' + tarea, showlegend=True, polar = dict(radialaxis = dict(showticklabels=True, tickangle = 90, angle = 25), angularaxis = dict(showticklabels=True)))
  namefig = 'medidas_globlales_fun_' + tarea + '.png'
  ffig = join(home_figuras, 'analisis global', namefig)
  fig.write_image(ffig)
  fig.show()

# %%
tareas = ['Social_Task_TOM_Perc_TOM']
sexos = ['F', 'M']
puntuaciones = ['+', '-']

for tarea in tareas:
  for sexo in sexos:
    for puntuacion in puntuaciones:

      # Se carga la lista de sujetos de la poblacion al vector sujetos
      name = tarea + '_' + puntuacion + '_' + sexo + '_sujetos.npy'
      fname = join(fdatapoblaciones, name)
      subjects_total = np.load(fname)

      data_sujetos = data.loc[subjects_total]

      name = tarea + '_' + puntuacion + '_' + sexo + '_psicometricos.xlsx'
      group = sexo + puntuacion + tarea
      fname = join(fdatapoblaciones, group, name)
      data_sujetos.to_excel(fname)
